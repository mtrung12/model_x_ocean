# %%
from pathlib import Path
import sys

import pandas as pd

project_root = Path.cwd().resolve()
if not (project_root / "baselines").exists():
    project_root = (project_root / ".." / "..").resolve()

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from baselines.evaluate import evaluate
from baselines.predict import predict
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 13
#      10 if str(project_root) not in sys.path:
#      11     sys.path.insert(0, str(project_root))
# ---> 13 from baselines.evaluate import evaluate
#      14 from baselines.predict import predict
#
# File F:\std\GR\code\model_x_ocean\baselines\__init__.py:2
#       1 from .prompt import *
# ----> 2 from .predict import *
#       3 from .evaluate import *
#
# File F:\std\GR\code\model_x_ocean\baselines\predict.py:6
#       3 import time
#       5 from baselines.prompt import *
# ----> 6 from utils.gpt_client import gpt_call
#       7 from utils.hf_client import hf_call
#       8 from utils.log import log_to_file
#
# File F:\std\GR\code\model_x_ocean\utils\__init__.py:2
#       1 from .log import log_to_file
# ----> 2 from .parser import extract_cot_result, extract_oneshot_result, extract_zeroshot_result
#       3 from .gpt_client import gpt_call
#       4 from .hf_client import hf_call
#
# ImportError: cannot import name 'extract_cot_result' from 'utils.parser' (F:\std\GR\code\model_x_ocean\utils\parser.py)

# %%
test_df = pd.read_csv(project_root/"data/split/essays/test.csv")
model_name = "gpt-4o-mini"
temperature = 0
res_dir = str(project_root / "result")
log_dir = str(project_root / "log")
max_new_tokens = 512

# %%
run_id, run_time, prediction_csv = predict(
    text_df=test_df,
    model_name=model_name,
    log_dir=log_dir,
    prompt_mode="cot",
    max_new_tokens=max_new_tokens,
    res_dir=res_dir,
    temperature=temperature
)

# %%
evaluation = evaluate(
    prediction_csv=prediction_csv,
    model_name=model_name,
    res_dir=res_dir,
    run_time=run_time,
    prompt_mode="cot",
    run_id=run_id
)
