# %%
from pathlib import Path
import sys

import pandas as pd

project_root = Path.cwd().resolve()
if not (project_root / "baselines").exists():
    project_root = (project_root / ".." / "..").resolve()

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from baselines.evaluate import evaluate
from baselines.predict import predict

# %%
test_df = pd.read_csv(project_root/"data/split/essays/test.csv")
model_name = "gpt-4o-mini"
temperature = 0
res_dir = str(project_root / "result")
log_dir = str(project_root / "log")
max_new_tokens = 512

train_df = pd.read_csv(project_root/"data/split/essays/train.csv")

# %%
run_id, run_time, prediction_csv = predict(
    text_df=test_df,
    model_name=model_name,
    log_dir=log_dir,
    prompt_mode="oneshot",
    max_new_tokens=max_new_tokens,
    res_dir=res_dir,
    temperature=temperature,
    example_df=train_df,
)
# Out:
# Loaded 247 records.
# Processed 10/247 records.
# Processed 20/247 records.
# Processed 30/247 records.
# Processed 40/247 records.
# Processed 50/247 records.
# Processed 60/247 records.
# Processed 70/247 records.
# Processed 80/247 records.
# Processed 90/247 records.
# Processed 100/247 records.
# Processed 110/247 records.
# Processed 120/247 records.
# Processed 130/247 records.
# Processed 140/247 records.
# Processed 150/247 records.
# Processed 160/247 records.
# Processed 170/247 records.
# Processed 180/247 records.
# Processed 190/247 records.
# Processed 200/247 records.
# Processed 210/247 records.
# Processed 220/247 records.
# Processed 230/247 records.
# Processed 240/247 records.
# Finished in 1448.75 seconds.
# Saved to: F:\std\GR\code\model_x_ocean\result\gpt-4o-mini\oneshot\20260424-141553\predictions.csv

# %%
evaluation = evaluate(
    prediction_csv=prediction_csv,
    model_name=model_name,
    res_dir=res_dir,
    run_time=run_time,
    prompt_mode="oneshot",
    run_id=run_id
)
# Out:
# Loaded predictions from F:\std\GR\code\model_x_ocean\result\gpt-4o-mini\oneshot\20260424-141553\predictions.csv
# Saved evaluation summary to F:\std\GR\code\model_x_ocean\result\gpt-4o-mini\oneshot\20260424-141553\evaluation_summary.csv
# Saved Openness report to F:\std\GR\code\model_x_ocean\result\gpt-4o-mini\oneshot\20260424-141553\Openness_classification_report.txt
# Saved Conscientiousness report to F:\std\GR\code\model_x_ocean\result\gpt-4o-mini\oneshot\20260424-141553\Conscientiousness_classification_report.txt
# Saved Extraversion report to F:\std\GR\code\model_x_ocean\result\gpt-4o-mini\oneshot\20260424-141553\Extraversion_classification_report.txt
# Saved Agreeableness report to F:\std\GR\code\model_x_ocean\result\gpt-4o-mini\oneshot\20260424-141553\Agreeableness_classification_report.txt
# Saved Neuroticism report to F:\std\GR\code\model_x_ocean\result\gpt-4o-mini\oneshot\20260424-141553\Neuroticism_classification_report.txt
